# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Владимир :)  Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, <b>интерпретации значения p-value - можно повторить недели через две </b>(для профилактики 🤝 )
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# оставил комментарий про расшифровку р-значения, добавил бонус и одну подсказку

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Владимир :) Спасибо за доработки 🤝
#
# Критические ❌ комментарии связаны с неточностями:
#
#
#  + создать выборку в подразделе портретов из ТОП-5 и категории «другие»
#  + в разделе проверки гипотез  можно более подробно расшифровать значение p_value
#  + поправить пару выводов
#
# новые подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Владимир :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# __Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие, а ты попробуешь исправить ее самостоятельно. Но если ты пока не справишься с такой задачей — при следующей проверке я дам более подробную подсказку!__
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование о закономерности , определяющие успешность игры
# В данном проекте нам предстоит выяснить , какие закономерности влияют на успех игры. Также определить , какой продукт может стать популятным и спланировать для него рекламную компанию. Спрагнозировать продажи на 2017 год

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название стоит переместить в начало проекта

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# # Содержание

# %% [markdown]
# **1 Изучение данных из файла**
#
#     1.1 Загрузим и изучим датафрейм
#     1.2 Вывод
#
# **2 Предобработка данных**
#
#     2.1  Переведем название столбцов в нижний регистр
#     2.2  Приведем год релиза и оценку критиков к целочисленому значению
#     2.3  Обработаем столбец 'user_score'
#     2.4  Заполним пропуски в столбце 'rating'
#     2.5  Подсчитаем сумму продаж для каждого продукта со всех регионов
#     2.6  Обработаем дубликаты
#     2.7  У платформы 'DS'  имеются аномальные значения в столбце 'year_of_release'
#     2.8  Вывод
#
# **3 Исследовательский анализ данных**
#
#     3.1 Информация за неполный 2016 год
#     3.2 Построим график , чтобы увидеть в какие года выходило больше игр
#     3.3 Построим график , чтобы увидеть на какие платформы выходило больше игр
#     3.4 Платформы, которые принесли больше денег
#     3.5 За какой характерный срок появляются новые и исчезают старые платформы
#     3.6 Создадим датафрейм с данными за актуальный период
#     3.7 Посмотрим на продажи актуальных платформ. Построим 'ящик с усами'
#     3.8 Посмотрим,как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков
#     3.9 Оценим продажи еще для двух популярных платформ X360 и PS4
#     3.10 Узнаем популярные жанры за актуальных период
#     3.11 Вывод
#
# **4 Портрет пользователя каждого региона**
#
#     4.1 Построим графики по продажам по платформам , жанрам и рейтингу для каждого региона
#     4.2 Вывод
#
# **5 Проверка гипотез**
#
#     5.1 Проверим гипотезу о том , одинаковые ли оценки у двух плотформ
#     5.2 Средние пользовательские рейтинги жанров Action  и Sports разные
#     5.3 Вывод
#
# **6 Общий вывод**

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить одну из ключевых особенностей описания проекта — данные за 2016 г. неполные

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить одну из ключевых особенностей описания проекта

# %%
from math import sqrt
from scipy import stats as st
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Загрузим и изучим датафрейм

# %%
data = pd.read_csv('/datasets/games.csv')

# %%
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
# check
# пропущенные значения бары

def pass_value_barh(dfg):
    try:
        (
            (dfg.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>Как я понял , по оси Х указано среднее колическтво пропусков , а не реальное колическтво пропусков + я бы добавил grid</b></font>

# %%
# check
import numpy as np
pd.Series([1, np.nan, 6]).isna()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
# check
pd.Series([False,True,False]).mean().round(4)*100
# Out:
# 33.33

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Считаем процент пропусков

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, к вопросу сетки вернемся на втором модуле
#
# Цвет у шрифта заголовка почти совпадает с цветом у баров
#
# За поворот текста на оси `Y` отвечает параметр `rot`
#
# Можно добавить обозначение оси `Х` (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         ;
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100
#
#         plt.xlim(0, 100)
#
# часть моих новых шрифтов оформлена не совсем корректно 🤝😉

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Посмотри на явные и неявные дубликаты

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать неполные дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %%
data.loc[data.duplicated(['Name', 'Platform','Year_of_Release'])]
# Out:
#                 Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 14244            NaN      GEN           1993.0     NaN       0.0      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports       0.0      0.01
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 14244      0.03          0.0           NaN        NaN    NaN
# 16230      0.00          0.0          83.0        5.5      E

# %% [markdown]
# ### Вывод: После загрузки датафрейма , мы видим что , в таблице содержится 16715 строк и 11 столбцов . Также видно что в столбцах 'name', 'year_of_release', 'genre', 'critic_score', 'user_score', 'rating'  есть пропуски.  Явных дубликатов нет. Есть неявные дубликаты в датафрейме , обработаем их в следующем разделе.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Обзор данных выполнен корректно, применены методы .head() и .info(), промежуточный вывод добавлен, молодец

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Переведем название столбцов в нижний регистр

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# ### Приведем год релиза и оценку критиков к целочисленому значению

# %%
data['critic_score'] = data['critic_score'].astype('Int64')
data['year_of_release'] = data['year_of_release'].astype('Int64')

# %% [markdown]
# ### Обработаем столбец 'user_score'

# %%
data.loc[data['user_score'] =='tbd','user_score'] = np.nan
data['user_score'] = data['user_score'].astype('float64')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# #### TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято. Т.е данные отсутствуют и tbd можно заменить на nan .

# %% [markdown]
# ### Заполним пропуски в столбце 'rating'

# %%
data['rating'] = data['rating'].fillna('NO')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличное решение для столбца, который содержит категориальные данные, поможет определить ключевое различие в потрете пользователя
#
#         ... .fillna('NO')
#
# Можно посмотреть на частотность использования категорий рейтинга, по отношению к остальным
#
#         EC         8
#         K-A        3
#         RP         1
#         AO         1

# %% [markdown]
# #### рейтинг от организации ESRB . Данная огранизация расположенна в Северной Америке и оценивает игры для этого региона , также как для Европы есть 'PEGI' и для азии 'CERO'(все данные из википедии). Соответвенно игры которые остались без рейтинга оценивались другими огранизациями , для другого региона. Также можно учесть что в подборке есть игры старше 1996г выпуска(организация ESRB основана в 1996г), и данная организация никак не могла оценить такой продукт.

# %% [markdown]
# ### Подсчитаем сумму продаж для каждого продукта со всех регионов

# %%
data['total_sales'] = (data['na_sales']+data['eu_sales']+data['jp_sales']+data['other_sales'])

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
data['total_sales']
# Out:
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# 4        31.38
#          ...
# 16710     0.01
# 16711     0.01
# 16712     0.01
# 16713     0.01
# 16714     0.01
# Name: total_sales, Length: 16715, dtype: float64

# %% [markdown]
# #### Как видно по подсчетам , некоторые продукты слабо продаются

# %% [markdown]
# ### Обработаем дубликаты

# %%
data.loc[
    ((data['name'].isna()) &  
    (data['year_of_release'] == 1993)) | 
    ((data['name'] == 'Madden NFL 13') & 
    (data['platform'] == 'PS3') & 
    (data['year_of_release'] == 2012))
]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 659              NaN      GEN             1993     NaN      1.78      0.53
# 14244            NaN      GEN             1993     NaN      0.00      0.00
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  total_sales
# 604        0.00         0.23            83         5.5      E         2.56
# 659        0.00         0.08          <NA>         NaN     NO         2.39
# 14244      0.03         0.00          <NA>         NaN     NO         0.03
# 16230      0.00         0.00            83         5.5      E         0.01

# %%
data = data.dropna(subset=['name', 'genre'])
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating                0
# total_sales           0
# dtype: int64

# %%
data = data.drop_duplicates(subset=['name', 'platform', 'year_of_release']).reset_index(drop=True)
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating                0
# total_sales           0
# dtype: int64

# %%
data.loc[(data['name'] == 'Madden NFL 13')]
# Out:
#                name platform  year_of_release   genre  na_sales  eu_sales  \
# 507   Madden NFL 13     X360             2012  Sports      2.53      0.15
# 604   Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 3985  Madden NFL 13      Wii             2012  Sports      0.47      0.00
# 5886  Madden NFL 13      PSV             2012  Sports      0.28      0.00
# 7065  Madden NFL 13     WiiU             2012  Sports      0.21      0.00
#
#       jp_sales  other_sales  critic_score  user_score rating  total_sales
# 507        0.0         0.17            81         5.8      E         2.85
# 604        0.0         0.23            83         5.5      E         2.56
# 3985       0.0         0.03          <NA>         7.3      E         0.50
# 5886       0.0         0.02            63         7.3      E         0.30
# 7065       0.0         0.02            75         6.7      E         0.23

# %% [markdown]
# #### При изучении информации в первом разделе в столбцах  'name' и 'genre' было по два пропуска. Просмотрев информацию о пропусках в этих столбцах можо сказать , что информации о данных играх мало . Предлагаю эти две строки удалить.Также были неявные дубликаты связанные с игрой 'Madden NFL 13'.

# %% [markdown]
# ### У платформы 'DS'  имеются аномальные значения в столбце 'year_of_release' , удалим их

# %%
ds=data.query('platform==["DS"]')
ds.describe()
# Out:
#        year_of_release     na_sales     eu_sales     jp_sales  other_sales  \
# count      2121.000000  2151.000000  2151.000000  2151.000000  2151.000000
# mean       2008.185290     0.177778     0.087815     0.081623     0.027550
# std           1.778565     0.533684     0.493852     0.392268     0.127893
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2007.000000     0.000000     0.000000     0.000000     0.000000
# 50%        2008.000000     0.060000     0.000000     0.000000     0.010000
# 75%        2009.000000     0.170000     0.020000     0.030000     0.020000
# max        2013.000000    11.280000    10.950000     6.500000     2.880000
#
#        critic_score  user_score  total_sales
# count    717.000000  516.000000  2151.000000
# mean      63.761506    7.025194     0.374765
# std       13.575478    1.508264     1.426451
# min       19.000000    0.000000     0.010000
# 25%       56.000000    6.475000     0.050000
# ...

# %%
ds.query('year_of_release==[1985]')
# Out:
#                                       name platform  year_of_release   genre  \
# 15955  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15955       0.0       0.0      0.02          0.0          <NA>         NaN
#
#       rating  total_sales
# 15955     NO         0.02

# %%
index = data[(data['name']=='Strongest Tokyo University Shogi DS')&(data['year_of_release']== 1985)].index
data.drop(index,inplace=True)
data.reset_index(drop=True)
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16706  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16707               LMA Manager 2007     X360             2006        Sports
# 16708        Haitaka no Psychedelica      PSV             2016     Adventure
# 16709               Spirits & Spells      GBA             2003      Platform
# 16710            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
#data = data.drop(data.index[15955], inplace=False).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Удаление по индексу строки может привести к малозаметным ошибкам, которые трудно обнаружить
#
#         любое изменение выборки до кода удаления приведет к необходимости исправлять все индексы на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %%
data.loc[(data['platform'] == 'DS') & (data['year_of_release']== 1985)]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []

# %% [markdown]
# ### Вывод: <br/> В данном разделе я произвел предобработку данных . Мой были удалены две строки , которые имели недостаточное количество информации для дольнейшей работы. Заменены пропуски в столбце 'rating'. Засенено значение tbd в столбце 'user_score' на NaN. Приведены к целочисленному значению 'critic_score' , 'year_of_release'.<br/> Столбцы 'year_of_release', 'critic_score', 'user_score' решил оставить без изменения. 'year_of_release' не трогал , проекты из списка у которых нет релиза ,могли закрыться на статии закрытых альва или бета тестирований . Также не стоит исключать человеческий фактор , особенно в случае , если игра была выпушена давно , данные просто могли затерятся . <br/> Что касается 'critic_score',	'user_score' , так как это оценочные показатели , заменять из медианой или средним не стоит , потому-что оценки для пропущенных значений могут оказаться неправдаподобными и сказаться на дальнейших результатах.<br/> Удалена аномалия в столбце 'platform'.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Верное решение для этого проекта, молодец
#
#          заменять из медианой или средним не стоит

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, добавлен промежуточный вывод, молодец

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Информация за неполный 2016 год

# %%
year_16 = data.query('year_of_release == 2016')
year_16.sample(10)
# Out:
#                                                     name platform  \
# 14507                                         Worms: WMD      PS4
# 15780                       Taishou Moebius Line Vitable      PSV
# 13914      Metal Gear Solid V: The Definitive Experience      PS4
# 3507                                         Titanfall 2     XOne
# 8882                                          Battleborn     XOne
# 14945  TV Anime Idolm@ster: Cinderella Girls G4U! Pac...      PS3
# 2209                                     EA Sports UFC 2      PS4
# 14206         Duke Nukem 3D: 20th Anniversary World Tour      PS4
# 10969                                             MXGP 2      PS4
# 3364                                            WWE 2K17      PS4
#
#        year_of_release      genre  na_sales  eu_sales  jp_sales  other_sales  \
# 14507             2016     Action      0.01      0.02      0.00         0.00
# 15780             2016  Adventure      0.00      0.00      0.02         0.00
# ...

# %%
year_16['total_sales'].sum()
# Out:
# 129.94

# %% [markdown]
# #### Как видно из таблицы за неполный 2016 год , популярными платформами являются XOne и PS4 .

# %% [markdown]
# ### Построим график , чтобы увидеть в какие года выходило больше игр

# %%
year_name_count = data.pivot_table(index=['year_of_release'], values='name',aggfunc='count')
year_name_count.plot(kind='bar', figsize =(10,6), grid=True, legend=False, color='g')
plt.title('Распределиние выхода игр по годам',fontsize=20)
plt.locator_params(axis="x", nbins=9)
plt.xlabel('Год выпуска')
plt.ylabel('Количество игр')

plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит развернуть надписи на оси Х

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец
#
#         стоит сократить кол-во подписей оси Х: 1980-1985-1990 ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# #### В середине 90х годов начался медленный рост игровой индострии. Концу 90х началу 00х видно как игровая индустрия набирала обороты. В 2002 году виден резкий рост , можно это связать с тем , что на свет появилась первая консоль от MICROSOFT - XBOX. С 2005 по 2009 год график рос , в эти года выходили PS3 и XBOX 360. Дальше график идет на спад , как мне кажется это связано с ростом популярности онлайн игр(DOTA2 , CS , WoT), также на этот промежуток времени упал рость популярность мобильных игр

# %% [markdown]
# ### Построим график , чтобы увидеть на какие платформы выходило больше игр

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a> ⬇⬇
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %%
platform_name_count = (
    data.pivot_table(index=['platform'], values='name',aggfunc='count')
    .sort_values(by='name', ascending=False)
)
platform_name_count.plot(y='name',kind='bar', figsize =(10,6),
                         legend=False, color='g', grid=True)
plt.title('Распределиние выхода игр по годам',fontsize=15)
plt.xlabel('Платформа')
plt.ylabel('Количество игр')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Видны два явных фаворита , это PS2 и DS(портативная консоль от Nintendo) , количестно игр превышает 2000. На такие консоли как PS4 и XOne вышли лишь в 2013 году , по этому большого количества игр на них не могло выйти. Платформы 3DO ,TG16,PCFX,GG не пользуются популярностью

# %% [markdown]
# ###  Платформы, которые принесли больше денег

# %%
platform_ts_sum = (
    data.pivot_table(index=['platform'], values='total_sales',aggfunc='sum')
    .sort_values(by='total_sales', ascending=False)
)
platform_ts_sum.plot(kind='bar', figsize =(10,6), legend=False, color='g', grid=True)
plt.title('Распределиние выхода игр по годам',fontsize=15)
plt.xlabel('Платформа')
plt.ylabel('Кол-во продаж(млн)')
plt.xticks(rotation=45)
plt.show()

# %%
top_pl = platform_ts_sum.sort_values(by='total_sales', ascending=False)[0:10]
top_pl
# Out:
#           total_sales
# platform
# PS2           1255.77
# X360           971.42
# PS3            939.64
# Wii            907.51
# DS             806.10
# PS             730.86
# GBA            317.85
# PS4            314.14
# PSP            294.05
# PC             259.52

# %% [markdown]
# #### Как и с количеством игр , PS2 возглавляет список . В след за ней расположились X360,PS3,Wii,DS,PS. 3DO ,TG16,PCFX,GG,SCD,NG,WS - не популярные платформы , если у них был доход , то очень маленький

# %% [markdown]
# ### За какой характерный срок появляются новые и исчезают старые платформы

# %%
best_pl = data.query('platform==["PS2","X360","PS3","Wii","DS","PS"]')

# %%
top_pl_plot = best_pl.pivot_table(index=['year_of_release'],
                    columns=['platform'],
                    values=['total_sales'],
                    aggfunc=['sum'])
top_pl_plot.plot(kind='line', figsize =(15,10),grid=True, linewidth=2.0)
plt.xlabel('ГОД')
plt.ylabel('Кол-во')
plt.legend()
plt.show()

# %% [markdown]
# #### На графике видны популярные платформы за весь период. Данные платформы к 2016 году перестали пользоваться популярностью , либо просто устарели.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>сделал это в пункте 2.7</b></font>

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# ### Создадим датафрейм с данными за  актуальный период.

# %%
act_year = data.query('year_of_release >= 2013')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>Я так понимаю , что луше было бы взять выборку начиная в 2014 года ? В пачке спрашивал у студентов , какой актуальный год писали , кто-то 2012 , кто-то 2014 . В итоге решил не трогать этот параметр</b></font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Покажу пример влияния этого параметра в бонусной части, после завершения проекта

# %%
act_year
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 16700               Strawberry Nauts      PSV             2016     Adventure
# 16704               Aiyoku no Eustia      PSV             2014          Misc
# 16707  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16709        Haitaka no Psychedelica      PSV             2016     Adventure
# 16711            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
act_pl = act_year.pivot_table(index=['year_of_release'],
                     columns=['platform'],
                     values=['total_sales'],
                     aggfunc=['sum'])
act_pl.plot(kind='line', figsize =(10,8),grid=True, linewidth=2.0)
plt.locator_params(axis="x", nbins=5)
plt.xlabel('ГОД')
plt.ylabel('Кол-во')
plt.legend()
plt.show()

# %% [markdown]
# #### Актуальный период предлагаю начинать в 2013 года , т.к именно в этот год стали выпускать консоли 'нового' покаления(PS4 , XOne). Именно к этих двух платвом виден рост с 2013 по 2016 год. Можно предположить , что именно на эти платформы будет делаться упор в ближайшие 5-6 лет.  Если учитывать , что предыдущие поколения консолей 'жили' от 8 до 10 лет

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Можно подправить подписи оси х, в виде целых 2014, 2015 ...,
#
# искать тему Ticks and ticklabels
#
# https://matplotlib.org/stable/tutorials/text/text_intro.html
#
# или
#
# https://dev-gang.ru/article/izmenenie-czastoty-tikov-v-matplotlib-k5x1kznn39/?ysclid=lcp5si8pky848462627

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# ### Посмотрим на продажи актуальных платформ. Построим 'ящик с усами'

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.boxplot(x=act_year['total_sales'],
            y=act_year['platform'])
plt.title('Глобальные продажи игр в разбивке по платформам',fontsize = 20)
plt.ylabel('Платформа')
plt.xlabel('Кол-во продаж')
plt.grid(color='grey', axis='both', alpha=0.5)
plt.xlim(0,2)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.boxplot(x=act_year['total_sales'],
            y=act_year['platform'])
plt.title('Глобальные продажи игр в разбивке по платформам',fontsize = 20)
plt.ylabel('Платформа')
plt.xlabel('Кол-во продаж')
plt.grid(color='grey', axis='both', alpha=0.5)
plt.xlim(0,17.5)
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)
#
# https://stackoverflow.com/questions/22028064/matplotlib-boxplot-without-outliers

# %% [markdown]
# #### Как видим на график , у всех платформ медианное значение находится в межквантильном размехе. Также у большинства платфор имеются выбросы , можно чтитать это за успешные проекты .Можно выделить четыре платформы с максимальными продажами 'PS3','X360','PS4','3DS'.

# %%
ps3 = act_year.query('platform == "PS3"').reset_index(drop=True)
ps3
# Out:
#                                                   name platform  \
# 0                                   Grand Theft Auto V      PS3
# 1                                 Call of Duty: Ghosts      PS3
# 2                                              FIFA 14      PS3
# 3                                       The Last of Us      PS3
# 4                                            Minecraft      PS3
# ..                                                 ...      ...
# 340  Naruto Shippuden: Ultimate Ninja Storm Collection      PS3
# 341                                Tour de France 2014      PS3
# 342                      Tsukigime Ranko's Longest Day      PS3
# 343                       Dynasty Warriors: Eiketsuden      PS3
# 344                      Samurai Warriors: Sanada Maru      PS3
#
#      year_of_release    genre  na_sales  eu_sales  jp_sales  other_sales  \
# 0               2013   Action      7.02      9.09      0.98         3.96
# ...

# %% [markdown]
# ### Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. В нашем случае это PS3.

# %%
ps3.pivot_table(index='name', values=['critic_score','user_score','total_sales']).corr().round(2)
# Out:
#               critic_score  total_sales  user_score
# critic_score          1.00         0.33         0.6
# total_sales           0.33         1.00         0.0
# user_score            0.60         0.00         1.0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         total_sales	0.334285	1.000000	0.002394

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %%
ps3.plot.scatter (x = 'critic_score', y = 'total_sales',figsize =(7,5),grid=True)
plt.title('Зависимость продаж от отзыва критиков')
plt.xlabel('Оценка',fontsize=15)
plt.ylabel('Кол-во',fontsize=15)
plt.show()

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит перерисовать все точечные диаграммы без применения сводных таблиц
#
# Можно попробовать настроить вид точечных графиков
#
# [Как сделать диаграмму рассеяния из фрейма данных Pandas](https://www.codecamp.ru/blog/pandas-scatter-plot/?ysclid=lh0tbpkoa9628147030)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)
#
#
# [Примеры графиков](https://proglib.io/p/kollekciya-prodvinutoy-vizualizacii-v-matplotlib-i-seaborn-s-primerami-2021-02-11?ysclid=ltnocrlmos378496858)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %%
ps3.plot.scatter (x = 'user_score', y = 'total_sales',figsize =(7,5),grid=True)
plt.title('Зависимость продаж от отзыва критиков')
plt.xlabel('Оценка',fontsize=15)
plt.ylabel('Кол-во',fontsize=15)
plt.show()

# %% [markdown]
# #### По корреляции и графикам видно , что оценки критиков и пользователей в единичных случаях влияют на продажи.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить парочку диаграмм рассеяния, коэф. корреляции отображает лишь возможное наличие линейной связи

# %% [markdown]
# ### Оценим продажи еще для двух популярных платформ XOne и PS4.

# %%
xb = act_year.query('platform == "XOne"').reset_index(drop=True)
xb.pivot_table(index='name', values=['critic_score','user_score','total_sales']).corr().round(2)
# Out:
#               critic_score  total_sales  user_score
# critic_score          1.00         0.42        0.47
# total_sales           0.42         1.00       -0.07
# user_score            0.47        -0.07        1.00

# %%
xb.plot.scatter (x = 'user_score', y = 'total_sales',figsize =(5,4),grid=True)
plt.title('Зависимость продаж от отзыва критиков')
plt.xlabel('Оценка',fontsize=15)
plt.ylabel('Кол-во',fontsize=15)
plt.show()

# %%
ps4 = act_year.query('platform == "PS4"').reset_index(drop=True)
ps4.pivot_table(index='name', values=['critic_score','user_score','total_sales']).corr().round(2)
# Out:
#               critic_score  total_sales  user_score
# critic_score          1.00         0.41        0.56
# total_sales           0.41         1.00       -0.03
# user_score            0.56        -0.03        1.00

# %%
ps4.plot.scatter (x = 'user_score', y = 'total_sales',figsize =(5,4),grid=True)
plt.title('Зависимость продаж от отзыва критиков')
plt.xlabel('Оценка',fontsize=15)
plt.ylabel('Кол-во',fontsize=15)
plt.show()

# %% [markdown]
# #### Как и в случает с PS3 , оценки пользователей и критиков мало значат. Но что у 'XOne' что у 'PS4' есть игры , на которые повлиели оценки

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит выполнить исследование зависимости продаж от оценок пользователей и критиков по платформам конкурентам — рассмотреть в этом разделе отдельно две-три платформы
#
#         ps4, xone
#
# Выводы, сделанные на основе расчетов по нескольким платформам выглядят "весомей" и убедительней

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение)

# %% [markdown]
# ### Узнаем популярные жанры за актуальных период.

# %%
(
    act_year.pivot_table(index=['genre'],values=['total_sales'],aggfunc=['sum'])
     .plot(y='sum',kind='bar', figsize =(10,5),grid=True)
)
plt.title('Актуальные жанры',fontsize = 20)
plt.xlabel('Жанр')
plt.ylabel('Кол-во')
plt.legend('')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.boxplot(x=act_year['total_sales'],
            y=act_year['genre'])
plt.title('Глобальные продажи игр в разбивке по жанрам',fontsize = 20)
plt.ylabel('Платформа')
plt.xlabel('Кол-во продаж')
plt.grid()
plt.xlim(0,18)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.boxplot(x=act_year['total_sales'],
            y=act_year['genre'],
            showfliers=False)
plt.title('Глобальные продажи игр в разбивке жанрам',fontsize = 20)
plt.ylabel('Платформа')
plt.xlabel('Кол-во продаж')
plt.grid()
plt.xlim(0,1.5)
plt.show()

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Круговая диаграмма малоинформативна для кол-ва категорий более 5-ти, невозможно за 5 сек. сравнить и решить какой вид жанра является отстающим, а самое главное определить — насколько сильно они различаются друг от друга

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# #### Можно выделить 4 жанра которые пользуются популярностью на рынке, это Action, Shooter, Sports,Role-playing	. Можно выделить несколько популярных игр для каждого жанра . Sports - Fifa , Shooter - Call of Duty , Action - GTA , Role-plaing - Diablo. Всё это многолетные серии игр , с огромной базой поклонников . Остальные жанры , особенно Puzzle и Strategy сильно уступают по популярности.В жанре Action много выбросов (очень прибыльных игр). Из-за этого общая прибыль по жанру Action выше остальных. Но медианное значение продаж выше в жанре Shooter. Второе место по медианным продажам делят Platform и Sports

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# ### Вывод : <br/>  В данном разделе мы выяснили , в какие года выходило больше игр(2008,2009), самые популярные платформы за все время(PS2 и DS), популяные платформы начинаея с 2013 года(XOne,PS4). Поняли что оценки критиков и пользьзователей не влияют на продажи.Узнали какие жанры пользуются популятностью( Action, Shooter, Sports,Role-playing ).

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить перечень перспективных платформ
#
#
# даже  на падающих продажах можно заработать, когда объем составляет около 15-20 млн. копий, как например с 3DS
#
# 30-тилетняя история персональных компьютеров говорит, что игры для PC можно включить в рекомендацию

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить вывод
#
#         популяные платформы начинаея с 2013 года(PS3,X360,PS4).

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>+</b></font>

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# X360 и PS3 уже исполнилось 11 лет и они с малой вероятностью станут перспективными или сохранят продажи в 2017 году
#
#         популяные платформы начинаея с 2013 года(3DS,X360,PS4).

# %% [markdown]
# ##  Портрет пользователя каждого региона

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец
#
# Стоит оформить графики раздела TOП-5:
#
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>Как сделать несколько круговых диаграм , если честно так и не понял . Получилось только так , уверен что такое решение можно было бы написать через функцию , но пока что это сложно </b></font>

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# ### Построим графики по продажам по платформам , жанрам и рейтингу для каждого региона

# %%
na = (act_year.groupby('platform')['na_sales'].agg(na_sales='sum')
      .sort_values(by='na_sales', ascending=False).reset_index().head())
eu = (act_year.groupby('platform')['eu_sales'].agg(eu_sales='sum')
      .sort_values(by='eu_sales', ascending=False).reset_index().head())
jp = (act_year.groupby('platform')['jp_sales'].agg(jp_sales='sum')
      .sort_values(by='jp_sales', ascending=False).reset_index().head())
other_p = (act_year.groupby('platform')['other_sales'].agg(other_sales='sum')
      .sort_values(by='other_sales', ascending=False).reset_index().head())

fig, ax = plt.subplots(1, 4, figsize=(15, 5))
fig.suptitle('Продажи по платформам ', fontsize=20)

sns.barplot(y='na_sales', x='platform', data=na, ax=ax[0], palette='PuRd')
ax[0].set_title('Северная Америка')
ax[0].set_ylabel('продажи, млн.шт.')
ax[0].set_xlabel('платформа')

sns.barplot(y='eu_sales', x='platform', data=eu, ax=ax[1], palette='Paired_r')
ax[1].set_title('Европа')
ax[1].set_ylabel('продажи, млн.шт.')
ax[1].set_xlabel('платформа')

sns.barplot(y='jp_sales', x='platform', data=jp, ax=ax[2], palette='copper_r')
ax[2].set_title('Япония')
ax[2].set_ylabel('продажи, млн.шт.')
ax[2].set_xlabel('платформа')

sns.barplot(y='other_sales', x='platform', data=other_p, ax=ax[3], palette='gist_yarg')
ax[3].set_title('Без региона')
ax[3].set_ylabel('продажи, млн.шт.')
ax[3].set_xlabel('Жанр')
plt.show()

# %% [markdown]
# ### check

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Предлагаю попробовать создать шестую категорию — «Другие» и объединить туда все не вошедшие в ТОП-5 строчки
#
# Добавил пример создания строки (у меня он развернут в обратном порядке)
#
#
# На данном этапе интересует сама выборка ТОП-5 плюс категория «Другие», без графиков
#
# Если будут сложности с вариантом расчета сразу для трех регионов, стоит выполнить второй пример

# %% [raw]
# # check
# # import pandas as pd
# df_app = pd.DataFrame([['ps',1,2,3],
#                    ['xone',3,5,6],
#                    ['pc',8,9,10],
#                    ['ps3',1,7,3],
#                    ['ps4',5,2,3]], columns=['platform', 'eu','jp','na'])
# display(df_app)
#
# df_other = df_app[3:]
# df_other = df_other.append({'platform': 'Other', 'eu': df_app['eu'].sum()-df_app['eu'][3:].sum(),
#                   'jp': df_app['jp'].sum()-df_app['jp'][3:].sum(),
#                   'na': df_app['na'].sum()-df_app['na'][3:].sum()}, ignore_index = True)
# df_other

# %%
pl_ot = (
    act_year.groupby(['platform'])
    .agg({'na_sales' : sum,'eu_sales':sum,'jp_sales':sum})
    .sort_values(by='na_sales', ascending=False)
    .reset_index()
)
                                                                                                    
display(pl_ot)

df_other = pl_ot[:5]
df_other = df_other.append({'platform': 'Other', 'eu_sales': pl_ot['eu_sales'].sum()-pl_ot['eu_sales'][4:].sum(),
                  'jp_sales': pl_ot['jp_sales'].sum()-pl_ot['jp_sales'][:5].sum(),
                  'na_sales': pl_ot['na_sales'].sum()-pl_ot['na_sales'][:5].sum()},ignore_index=True)
df_other
# Out:
#    platform  na_sales  eu_sales  jp_sales
# 0       PS4    108.74    141.09     15.96
# 1      XOne     93.12     51.59      0.34
# 2      X360     81.66     42.52      0.51
# 3       PS3     63.50     67.81     23.35
# 4       3DS     38.20     30.96     67.81
# 5      WiiU     29.21     19.85     10.88
# 6        PC     11.11     25.36      0.00
# 7       Wii      6.56      5.93      0.05
# 8       PSV      5.04      6.10     18.59
# 9        DS      0.57      0.85      0.00
# 10      PSP      0.00      0.17      3.29
#   platform  na_sales  eu_sales  jp_sales
# 0      PS4    108.74    141.09     15.96
# 1     XOne     93.12     51.59      0.34
# 2     X360     81.66     42.52      0.51
# 3      PS3     63.50     67.81     23.35
# 4      3DS     38.20     30.96     67.81
# 5    Other     52.49    303.01     32.81

# %% [raw]
# df_app = (
#     act_year.pivot_table(index=['platform'] ,values=['eu_sales','na_sales', 'jp_sales'], aggfunc='sum')
#     .sort_values(by='eu_sales',ascending=False). reset_index()
# )
# display(df_app)
#
# df_other = df_app[:5]
# df_other = df_other.append({'platform': 'Other', 'eu_sales': df_app['eu_sales'].sum()-df_app['eu_sales'][:5].sum(),
#                   'jp_sales': df_app['jp_sales'].sum()-df_app['jp_sales'][5:].sum(),
#                   'na_sales': df_app['na_sales'].sum()-df_app['na_sales'][5:].sum()},ignore_index=True)
# df_other

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Или берем одну выборку ⬇⬇⬇ и создаем из неё выборку с 6-ю строчками.
#
# Это базовый навык работы с таблицей, навык по трансформации — из 11-ти строчек получить 6 в которой первые пять это топовые позиции, а последняя шестая — это сумма всех остальных строк, кроме первых пяти
#
# ![image.png](attachment:image.png)
#
# Если ты не понимаешь, как выполнить это, тогда стоит задать вопрос преподавателю по проектам в чате «пачки». Также ты можешь написать вопрос или пример кода в проекте и опять отправить его на проверку — так я смогу тебе ответить
#
#
# Можно посмотреть на порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948
#
# https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79 (ссылка может не работать)
#
# https://www.marsja.se/how-to-use-iloc-and-loc-for-indexing-and-slicing-pandas-dataframes/
#
#
# Выбор способа создания за тобой

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>Cделал 3 разных варианта . Если вариант ниже более менее просто и легко подобные примеры найти , то к варианту выше который ты оставил , я бы никогда не пришел( по крайней мере сейчас). Где можно почитать или видео посмотреть с подобными  примерами , можно даже англоязычные сайты и видео  </b></font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличная работа, молодец. Мой вариант не стоит брать за основу для будущей практики 🤝, т.к. метод append() устарел и на новой версии pandas (> 2) не работает
#
# Вариант с loc and iloc предпочтительнее
#
#
# __Осторожно, этот вариант не учитывает разный перечень в ТОП-5 для трех регионов__
#
# ![image.png](attachment:image.png)

# %%
nap = (act_year.groupby('platform')['na_sales'].agg(na_sales='sum')
      .sort_values(by='na_sales', ascending=False).reset_index())
nap.loc[5:,'platform'] = 'Other'
nap.loc[5,'na_sales'] =  nap.loc[5:,'na_sales'].sum().round(2)
nap = nap.iloc[0:6, :]
display(nap)

eup = (act_year.groupby('platform')['eu_sales'].agg(eu_sales='sum')
       .sort_values(by='eu_sales', ascending=False).reset_index())
eup.loc[5:,'platform'] = 'Other'
eup.loc[5,'eu_sales'] =  eup.loc[5:,'eu_sales'].sum().round(2)
eup = eup.iloc[0:6, :]
display(eup)

jpp = (act_year.groupby('platform')['jp_sales'].agg(jp_sales='sum')
       .sort_values(by='jp_sales', ascending=False).reset_index())
jpp.loc[5:,'platform'] = 'Other'
jpp.loc[5,'jp_sales'] =  jpp.loc[5:,'jp_sales'].sum().round(2)
jpp = jpp.iloc[0:6, :]
display(jpp)
# Out:
#   platform  na_sales
# 0      PS4    108.74
# 1     XOne     93.12
# 2     X360     81.66
# 3      PS3     63.50
# 4      3DS     38.20
# 5    Other     52.49
#   platform  eu_sales
# 0      PS4    141.09
# 1      PS3     67.81
# 2     XOne     51.59
# 3     X360     42.52
# 4      3DS     30.96
# 5    Other     58.26
#   platform  jp_sales
# 0      3DS     67.81
# 1      PS3     23.35
# 2      PSV     18.59
# 3      PS4     15.96
# 4     WiiU     10.88
# 5    Other      4.19

# %%
na_g = (act_year.groupby('genre')['na_sales'].agg(na_sales='sum')
      .sort_values(by='na_sales', ascending=False).reset_index().head())
eu_g = (act_year.groupby('genre')['eu_sales'].agg(eu_sales='sum')
      .sort_values(by='eu_sales', ascending=False).reset_index().head())
jp_g = (act_year.groupby('genre')['jp_sales'].agg(jp_sales='sum')
      .sort_values(by='jp_sales', ascending=False).reset_index().head())
other_g = (act_year.groupby('genre')['other_sales'].agg(other_sales='sum')
      .sort_values(by='other_sales', ascending=False).reset_index().head())

fig, ax = plt.subplots(1, 4, figsize=(15, 5))
fig.suptitle('Продажи по жанрам ', fontsize=20)
fig.autofmt_xdate(rotation=45)

sns.barplot(y='na_sales', x='genre', data=na_g, ax=ax[0], palette='PuRd')
ax[0].set_title('Северная Америка')
ax[0].set_ylabel('продажи, млн.шт.')
ax[0].set_xlabel('Жанр')

sns.barplot(y='eu_sales', x='genre', data=eu_g, ax=ax[1], palette='Paired_r')
ax[1].set_title('Европа')
ax[1].set_ylabel('продажи, млн.шт.')
ax[1].set_xlabel('Жанр')

sns.barplot(y='jp_sales', x='genre', data=jp_g, ax=ax[2], palette='copper_r')
ax[2].set_title('Япония')
ax[2].set_ylabel('продажи, млн.шт.')
ax[2].set_xlabel('Жанр')

sns.barplot(y='other_sales', x='genre', data=other_g, ax=ax[3], palette='gist_yarg')
ax[3].set_title('Без региона')
ax[3].set_ylabel('продажи, млн.шт.')
ax[3].set_xlabel('Жанр')
plt.show()

# %%
gr_ot = (
    act_year.groupby(['genre'])
    .agg({'na_sales' : sum,'eu_sales':sum,'jp_sales':sum})
    .sort_values(by='na_sales', ascending=False)
    .reset_index()
)
                                                                                                    
display(gr_ot)

gr_other = gr_ot[:5]
gr_other = gr_other.append({'genre': 'Other', 'eu_sales': gr_ot['eu_sales'].sum()-gr_ot['eu_sales'][:5].sum(),
                  'jp_sales': gr_ot['jp_sales'].sum()-gr_ot['jp_sales'][:5].sum(),
                  'na_sales': gr_ot['na_sales'].sum()-gr_ot['na_sales'][:5].sum()},ignore_index=True)
gr_other
# Out:
#            genre  na_sales  eu_sales  jp_sales
# 0         Action    126.05    118.13     40.49
# 1        Shooter    109.74     87.86      6.61
# 2         Sports     65.27     60.52      5.41
# 3   Role-Playing     46.40     36.97     51.04
# 4           Misc     27.49     20.04      9.20
# 5       Platform     18.14     15.58      4.79
# 6       Fighting     15.55      8.55      7.65
# 7         Racing     12.96     20.19      2.30
# 8      Adventure      7.14      8.25      5.82
# 9     Simulation      4.86     10.92      4.52
# 10      Strategy      3.28      4.22      1.77
# 11        Puzzle      0.83      1.00      1.18
#           genre  na_sales  eu_sales  jp_sales
# 0        Action    126.05    118.13     40.49
# 1       Shooter    109.74     87.86      6.61
# 2        Sports     65.27     60.52      5.41
# 3  Role-Playing     46.40     36.97     51.04
# 4          Misc     27.49     20.04      9.20
# 5         Other     62.76     68.71     28.03

# %%
na_r = (act_year.groupby('rating')['na_sales'].agg(na_sales='sum')
      .sort_values(by='na_sales', ascending=False).reset_index().head())
eu_r = (act_year.groupby('rating')['eu_sales'].agg(eu_sales='sum')
      .sort_values(by='eu_sales', ascending=False).reset_index().head())
jp_r = (act_year.groupby('rating')['jp_sales'].agg(jp_sales='sum')
      .sort_values(by='jp_sales', ascending=False).reset_index().head())
other_r = (act_year.groupby('rating')['other_sales'].agg(other_sales='sum')
      .sort_values(by='other_sales', ascending=False).reset_index().head())

fig, ax = plt.subplots(1, 4, figsize=(15, 5))
fig.suptitle('Продажи по рейтингу', fontsize=20)

sns.barplot(y='na_sales', x='rating', data=na_r, ax=ax[0], palette='PuRd')
ax[0].set_title('Северная Америка')
ax[0].set_ylabel('продажи, млн.шт.')
ax[0].set_xlabel('Жанр')

sns.barplot(y='eu_sales', x='rating', data=eu_r, ax=ax[1], palette='Paired_r')
ax[1].set_title('Европа')
ax[1].set_ylabel('продажи, млн.шт.')
ax[1].set_xlabel('Жанр')

sns.barplot(y='jp_sales', x='rating', data=jp_r, ax=ax[2], palette='copper_r')
ax[2].set_title('Япония')
ax[2].set_ylabel('продажи, млн.шт.')
ax[2].set_xlabel('Жанр')

sns.barplot(y='other_sales', x='rating', data=other_r, ax=ax[3], palette='gist_yarg')
ax[3].set_title('Без региона')
ax[3].set_ylabel('продажи, млн.шт.')
ax[3].set_xlabel('Жанр')

plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Заполнение пропусков в рейтинге позволило определить отличия региональных рынков, молодец

# %% [markdown]
# ### Вывод :<br/> - В продажах по платформам в Северной Америке и Европе лидирует PS4 и стоит замерить , что распределение рынка между платформати в Северной Америке  более плавное и нет большого разрыва как в Европе. Японцы же предпичитают 'местное производство' , в лидерах у них находится 3DS. В график 'без региона ' , повторяет Европейский рынок с PS4 в лидерах<br/> - В графиках продаж по жарнам Северно Американский и Европейским схожи в четырех позициях , это Action, Shooter,Sport,Role-playing , отличается только пятая позиция в топе , у СА это Misc ,  а у Европы Racing.У Японцев с лидерах с огромным отрыво Role-playing и Action , остальные жанры их как-будто не очень интересуют. График 'без региона ' повторяет СА рынок.<br/> -  Как и в предыдущих разбивках , СА и Европейский рырок похожи , в лидерах продаж игры с рейтингом M('Mature' — 'Для взрослых': Материалы игры не подходят для лиц младше 17 лет)  . Разница только в играх без рейтинга (NO) и E('Everyone' — 'Для всех': Содержание вполне подходит для всех возрастов (ранее с 6 лет) . В японском рейтинге с огромным отрывом лидирую игры без рейтинга . Можно предположить , что Японцы предпочитают игры производящиеся для внутреннего рынка , которые организация ESRB не оценивает.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Проверим гипотезу о том , одинаковые ли оценки у двух плотформ
#
# H0 - Средние пользовательские рейтинги платформ Xbox One и PC равны<br/>H1 - Средние пользовательские рейтинги платформ Xbox One и PC не равны

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
xbox = act_year[(act_year['platform'] == 'XOne') & (act_year['user_score'] > 0)]['user_score']
pc = act_year[(act_year['platform'] == 'PC') & (act_year['user_score'] > 0)]['user_score']
alpha=0.05
results = st.ttest_ind(xbox, pc)
print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')

print(f'xbox: {np.mean(xbox):.2f}')
print(f'pc: {np.mean(pc):.2f}')
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу
# xbox: 6.52
# pc: 6.27

# %% [markdown]
# #### Нет оснований отвергнуть нулевую гипотезу о равенстве средних значений оценок

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.14012658403611647

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>p-value больше уровня статистической значимости.Но это не значит что нулевая гипотеза точно верна.</b></font>

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.14012658403611647

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>Полученное значение p-value говорит о том, что средные оценки у XOne и PC неодинаковы ,с вероятностью в почти 14% такое или большее различие можно получить случайно.</b></font>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>Можно ли сказать , что 14% оценок в выборке одинаковые ?</b></font>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нет, 14% это совершенно про другое
#
# Смысл равенства средних значений в формулировке Н0 в том, что мы условно сравниваем выборочные средние значения двух выборок, а стат тест нам показывает вероятность того, насколько может быть случайным различие в средних
#
# и если р-значение почти равно нулю, значит вероятность случайной разности в средних незначительна, именно вероятность случайной разности, а следовательно мы отвергаем Н0, которая говорит, что средние равны
#
# а если р-значение почти равно единице, значит вероятность случайной разности в средних → высокая, именно вероятность СЛУЧАЙНОЙ разности высокая, и следовательно мы отвергаем Н1, которая говорит, что средние отличаются
#
# [Объяснение P-значений и статистической значимости](https://www.codecamp.ru/blog/p-values-statistical-significance/?ysclid=lm88qnc76l397155692)
#
# Слово случайно здесь ключевое
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
    
print(f's_1: {np.mean(sample_1):.2f}')
print(f's_2: {np.mean(sample_2):.2f}')
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу
# s_1: 2548.03
# s_2: 2115.67

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Скажи пожалуйста, имеет ли вес для объяснения результатов стат теста эта фраза
#
#         разнима между ними менее 4%

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>нет , т.к ориентироваться мы будем на гипотезы</b></font>

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# H0- оценки жанра 'Action' и жанра 'Sport' равны<br/>
# H1- оценки жанра 'Action' и жанра 'Sport' не равны

# %%
action = act_year[(act_year['genre'] == 'Action') & (act_year['user_score'] > 0)]['user_score']
sport = act_year[(act_year['genre'] == 'Sports') & (act_year['user_score'] > 0)]['user_score']
alpha=0.05
results = st.ttest_ind(action, sport)
print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
    
print(f'action: {np.mean(action):.2f}')
print(f'sport: {np.mean(sport):.2f}')
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу
# action: 6.84
# sport: 5.24

# %% [markdown]
# #### Отвергаем нулевую гипотезу о том, что средние пользовательские рейтинги жанров 'Action' и 'Sports' одинаковые.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить вывод
#
#         5.2.1  Отвергаем нулевую гипотезу , т.к разница между двумя жанрами более 23%
#
# https://allatambov.github.io/psms/pdf/hypo-test.pdf

# %% [markdown]
# ### Вывод:<br/> Проверили две гипотезы и пришли к выводу , что средние оценки на платформах PC и XOne равны , и во второй проверке отвергли нулевую гипотезу. <br/> В двух проверках пользовался двусторонней гипотезой и ttest_ind(Гипотеза о равенстве средних двух генеральных совокупностей)

# %% [markdown]
# ## Общий вывод:<br/> В данной работе мы проводии исследование о том, какие факторыи закономерности влияют на успешность игр. Были произведены следующие действия : <br/> - Изучена информация по датафрейму , убраны пропуски где это было возможно , обратобано значение 'tbd' в столбце 'user_score' , изменен тип данных в столбцах 'critic_score', 'year_of_release','user_score'. Подсчитали сумму продаж для каждого продукта со всех регионов ('total_sales').С необработанной таблице были найдены и удалены неполные дубликаты. Также были строки , где не было практически никакой информации о продукте. У платформы DS была обнаружена аномалия , с списке оказалась игра 1985 г.в , хотя платформа вышла только в 2004 году. Все аномалии и пропуски были удалены.   <br/>- Узнали в какие года выходило больше игр(2008,2009), самые популярные платформы за все время(PS2 и DS), популяные платформы начинаея с 2013 года(XOne,PS4). Поняли что оценки критиков и пользьзователей не влияют на продажи.Узнали какие жанры пользуются популятностью( Action, Shooter, Sports,Role-playing )<br/> - Сравнили три региона NA, EU,JP. В регионах NA и EU предпичитают играть на платформе PS4 и любимый жанр 'Action'. У JP региона в топах находятся 3DS и 'Role-playing'. <br/>- Провели гипотезу , где выяснили , что оценки пользователей на PC и XOne одинковые . Также проверили гипотезу о том ,что  у жанров 'Action' и 'Sport' одинаковые оценки , нулевую гипотезу пришлось отвергнуть.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить
#
#         популяные платформы начинаея с 2013 года(PS3,X360,PS4).

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исправить все подобные моменты
#
#         гипотеза подтвердилась.
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# https://allatambov.github.io/psms/pdf/hypo-test.pdf

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после  исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + выполнить проверку на дублирование записей
#  + добавить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез подправить выводы плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
# Плюс
#
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)

# %% [markdown]
# ## Бонус

# %%
import numpy as np

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие

# функция не работает на версии библиотеки pandas >= 2.0 (метод .append устарел)

def graph (df, year, region, name, axes):
    
# фильтруем выборку по переменной

    df = df.query('year_of_release >= @year')

# собираем ТОП-5

    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()

# добавляем 6-ю категорию в ТОП-5

    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
# меняем названия колонок, но неоптимальным способом 🤝

    sales.columns = ['platform', 'sales']

# создаем словарь цветов    
# Цветовая гамма не подбиралась специально под платформы, кому-что попадется, 😉 
      
    labels_c=sales.platform
    colours = {'Wii':'C60', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'lightsteelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'Fuchsia', '2600':'C15', 'PSP':'C48', 
               'XOne':'LimeGreen',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
# рисуем графики

    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
# устанавливаем границы для графиков, чтобы не перекрывали друг друга
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2013

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит обратить внимание на словарь цветов, когда на любом графике каждая платформа имеет свой цвет

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Я выбрал неудачный цвет для категории — «Другие», на темном фоне не видно цифры 😉
